# %%
# !python generate_dataset.py
# Out:
# Satellite Tensor Shape : torch.Size([32, 5, 64, 64])
# Weather Sequence Shape : torch.Size([32, 30, 6])
# Tabular Context Shape  : torch.Size([32, 12])
# Yield Target Shape     : torch.Size([32, 1])
# Stress Target Shape    : torch.Size([32])
